# %%
import pandas as pd
df = pd.read_csv('IMDb_spider.csv')
df
# Out:
#                                                 title  rating         year  \
# 0                                              Ahsoka     8.0     (2023– )
# 1                                           One Piece     8.4     (2023– )
# 2                                A Haunting in Venice     6.8       (2023)
# 3                                              Barbie     7.1   (I) (2023)
# 4                                           Elemental     7.0       (2023)
# 5                                          Talk to Me     7.2   (I) (2022)
# 6                                         Expend4bles     5.2       (2023)
# 7                                          Wilderness     6.3       (2023)
# 8        The Continental: From the World of John Wick     7.5       (2023)
# 9                                 Love at First Sight     6.9   (I) (2023)
# 10                                              Jawan     7.6       (2023)
# ...

# %%
# Out:
# {}
