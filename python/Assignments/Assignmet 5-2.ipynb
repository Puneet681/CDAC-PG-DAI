# %%
# 1. Write a menu driven program to practice String functions
# Design following meu
# a. display characters from even position
# b. display characters from odd position
# c. display length of a string
# d. add a at the end of string length times
# e. exit

n = input("""
a.Display Characters at even positions
b.Display Characters at odd positions
c.Display Lenght of String
d.Add 'a' at end of string
e.exit 
""")

s = "this is a prictice program"
k = []
k.extend(s)


if n == 'a':
    lt1 = "".join([k[i] for i in range(len(k)) if i%2 == 0])
    print(lt1)
elif n == 'b':
    lt1 = "".join([k[i] for i in range(len(k)) if i%2 != 0])
    print(lt1)
elif n == 'c':
    print("Lenght of the string is : ",len(s))
elif n == 'd':
    print((''.join(k))+"a"*len(s))
else:
    print("Thank you for Visting !")
# Out:
# Thank you for Visting !

# %%
# 2. Write a program to accept a string from user.
# Accept a second string from user to search and find all occurrences of in the given string.
# e.g
# s1=This is string
# check=is
# is-2
# is-5
# count=2

s = input("enter a string")
x = input("enter a substring too be found")

pos = s.find(x)
print(pos)
while pos !=-1:
    pos = s.find(x,pos+1)
    print(pos)
print(s.count(x))
# Out:
# -1
# 0

# %%
# 3. Write a menu driven program to practice List functions. Validate input data wherever
# required.
# Display following menu:
# 1. Accept Data
# a) add at last position
# b) add at given position
# 2. Delete data by value
# display message deleted successfully
# or not found
# 3. delete data by position
# a) delete last element
# b) delete from particular position
# 4. sort
# a) ascending
# b) descending
# 5. reverse
# 6. Print in sorted order without changing original list
# 7. print in reverse order without changing original list
# 8. display data
# a) normal
# b) numbered

def add_by_pos(l):
    in_ch = input('''a) add at last position
                        b) add at given position:- 
                        ''')
    if in_ch == 'a':
        val = int(input("enter the value"))
        status = add_at_last(l,val)
        if status == 1:
            print(f"{val} is added in list in {l}")
        else:
            print(f"{val} failed to add in list = {l}")
    if in_ch == 'b':
        val = int(input("enter the value"))
        pos = int(input("enter the position"))
        status = add_at_giv_pos(l,val,pos)
        if status == 1:
            print(f"{val} is added in list in {l}  at {pos}")
        elif status == 0:
            print(f"{val} failed to add in list = {l}  at {pos}")
def add_at_last(l,val):
    l.append(val)
    return 1
def add_at_giv_pos(l,val,pos):
    try:
        l[pos] = val
    except Exception as e:
        print(e)
        return 0
    return 1

def del_by_val(l):
    val = int(input("enter the value"))
    try:
        l.remove(val)
        print(f"{val} deleted from list = {l}")
    except Exception as e:
        print(e,f"\n{val} faild to delete")

def del_pos(l):
    in_ch = input('''a) delete last element
b) delete from particular position
''')
    if in_ch == 'a':
        status = del_at_last(l)
        if status == 1:
            print(f"last element deleted from list == {l}")
        else:
            print(f"fail to remove last element")
    elif in_ch == 'b':
        pos = input("enter position to del")
        status = del_by_pos(l,pos)
        if status == 1:
            print(f"element deleted from list == {l} from {pos}")
        else:
            print(f"fail to remove element from {pos}")
def del_at_last(l):
    try:
        print(l)
        del(l[len(l)-1])
        print(l)
        return 1
    except Exception as e:
        print(e)
        return None
def del_by_pos(l,pos):
    try:
        print([l])
        del(l[pos])
        print([l])
        return 1
    except Exception as e:
        print(e)
        return None
    
def soort(l):
    in_ch = input('''a) ascending
b) descending :- 
''')

    if in_ch == 'a':
        status , l = soort_acc(l)
        if status == 1:
            print(f"list is sorte in accending order = {l}")
        else:
            print(f"fail to sort the list")
    elif in_ch == 'b':
        status ,l = soort_dec(l)
        if status == 1:
            print(f"list is sorted in decending order = {l}")
        else:
            print(f"fail to sort list")
def soort_acc(l):
    l.sorrt()
    return 1,l
def soort_dec(l):
    l.soort(reverse = True)
    return 1,l

def rev(l):
    l.reverse()
    print(f"list has been reversed {l}")

def soort_NL(l):
    g = sorted(l)
    r = [i for i in g]
    print(f"orignal list = {l} \nsorted list = {r}")
    
def rev_NL(l):
    g = reversed(l)
    r = [i for i in g]
    print(f"orignal list = {l} \nreversed list = {r}")

def disp(l):
    in_ch = input('''a) normal
b) numbered:- ''')
    if in_ch == 'a':
        r = disp_nor(l)
        print(f"enterd list = {r}")
    elif in_ch == 'b':
        r = disp_numbered(l)
        print([["index = ",i, "value = ",c] for i,c in enumerate(l)])
    
        print(f" = {r}")
def disp_nor(l):
    r = [i for i in l]
    return r
def disp_numbered(l):
    r = [["index = ",i, "value = ",c] for i,c in enumerate(l)]
    
    return r


def main():
    
    lst = []
    
    try:
        i_str = input("enter the list to do oprations in CSV format")
        i_str = i_str.replace(',',"")
        lst.extend(i_str)
    except Exception as e:
        print(e)
        return None
    
    while True:

        choice = int(input('''enter your choice'
        1. Accept Data
        2. Delete data by value
        3. delete data by position
        4. sort
        5. reverse
        6. Print in sorted order without changing original list
        7. print in reverse order without changing original list
        8. display data choose
        -1. Exit : -'''))

    
            

        if choice == 1 :
            add_by_pos(lst)

        elif choice == 2 :
            del_by_val(lst)

        elif choice == 3 :
            del_pos(lst)
        
        elif choice == 4 :
            soort(lst)
        
        elif choice == 5 :
            rev(lst)
        
        elif choice == 6 :
            soort_NL(lst)
        
        elif choice == 7 :
            rev_NL(lst)
        
        elif choice == 8 :
            disp(lst)

        elif choice == -1:
            print("THANK YOU")
            break

main()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\CDAC PG-DAI\python\Assignments\Assignmet 5-2.ipynb Cell 3 line 2
#     <a href='vscode-notebook-cell:/d%3A/CDAC%20PG-DAI/python/Assignments/Assignmet%205-2.ipynb#W2sZmlsZQ%3D%3D?line=207'>208</a>             print("THANK YOU")
#     <a href='vscode-notebook-cell:/d%3A/CDAC%20PG-DAI/python/Assignments/Assignmet%205-2.ipynb#W2sZmlsZQ%3D%3D?line=208'>209</a>             break
# --> <a href='vscode-notebook-cell:/d%3A/CDAC%20PG-DAI/python/Assignments/Assignmet%205-2.ipynb#W2sZmlsZQ%3D%3D?line=210'>211</a> main()
#
# d:\CDAC PG-DAI\python\Assignments\Assignmet 5-2.ipynb Cell 3 line 1
#     <a href='vscode-notebook-cell:/d%3A/CDAC%20PG-DAI/python/Assignments/Assignmet%205-2.ipynb#W2sZmlsZQ%3D%3D?line=164'>165</a>     return None
#     <a href='vscode-notebook-cell:/d%3A/CDAC%20PG-DAI/python/Assignments/Assignmet%205-2.ipynb#W2sZmlsZQ%3D%3D?line=166'>167</a> while True:
# --> <a href='vscode-notebook-cell:/d%3A/CDAC%20PG-DAI/python/Assignments/Assignmet%205-2.ipynb#W2sZmlsZQ%3D%3D?line=168'>169</a>     choice = int(input('''enter your choice'
#     <a href='vscode-notebook-cell:/d%3A/CDAC%20PG-DAI/python/Assignments/Assignmet%205-2.ipynb#W2sZmlsZQ%3D%3D?line=169'>170</a>     1. Accept Data
#     <a href='vscode-notebook-cell:/d%3A/CDAC%20PG-DAI/python/Assignments/Assignmet%205-2.ipynb#W2sZmlsZQ%3D%3D?line=170'>171</a>     2. Delete data by value
#     <a href='vscode-notebook-cell:/d%3A/CDAC%20PG-DAI/python/Assignments/Assignmet%205-2.ipynb#W2sZmlsZQ%3D%3D?line=171'>172</a>     3. delete data by position
#     <a href='vscode-notebook-cell:/d%3A/CDAC%20PG-DAI/python/Assignments/Assignmet%205-2.ipynb#W2sZmlsZQ%3D%3D?line=172'>173</a>     4. sort
#     <a href='vscode-notebook-cell:/d%3A/CDAC%20PG-DAI/python/Assignments/Assignmet%205-2.ipynb#W2sZmlsZQ%3D%3D?line=173'>174</a>     5. reverse
#     <a href='vscode-notebook-cell:/d%3A/CDAC%20PG-DAI/python/Assignments/Assignmet%205-2.ipynb#W2sZmlsZQ%3D%3D?line=174'>175</a>     6. Print in sorted order without changing original list
#     <a href='vscode-notebook-cell:/d%3A/CDAC%20PG-DAI/python/Assignments/Assignmet%205-2.ipynb#W2sZmlsZQ%3D%3D?line=175'>176</a>     7. print in reverse order without changing original list
#     <a href='vscode-notebook-cell:/d%3A/CDAC%20PG-DAI/python/Assignments/Assignmet%205-2.ipynb#W2sZmlsZQ%3D%3D?line=176'>177</a>     8. display data choose
#     <a href='vscode-notebook-cell:/d%3A/CDAC%20PG-DAI/python/Assignments/Assignmet%205-2.ipynb#W2sZmlsZQ%3D%3D?line=177'>178</a>     -1. Exit : -'''))
#     <a href='vscode-notebook-cell:/d%3A/CDAC%20PG-DAI/python/Assignments/Assignmet%205-2.ipynb#W2sZmlsZQ%3D%3D?line=182'>183</a>     if choice == 1 :
#     <a href='vscode-notebook-cell:/d%3A/CDAC%20PG-DAI/python/Assignments/Assignmet%205-2.ipynb#W2sZmlsZQ%3D%3D?line=183'>184</a>         add_by_pos(lst)
#
# ValueError: invalid literal for int() with base 10: 'erd'

# %%
# 4. Create two lists to store cities and locations by accepting values from user.
# Display 1st city and 1st location
# then 2nd city and 2nd location ....... (zip function)

list1 = ["pune","akola","delhi","mumbai"]
list2 = [411007,444301,400001,123456]

tu = zip(list1 , list2)
 
for i in tu:
    print(i[0].ljust(6," ") , "------->",i[1],"\n")
# Out:
# pune   -------> 411007
#
# akola  -------> 444301
#
# delhi  -------> 400001
#
# mumbai -------> 123456

# %%
# 5. Create a list and exchange the values as index and index as values.
# lst=[12, 1, 3, 7, 8, 5, 8]
# 0 1 2 3 4 5 6

lst=[12, 1, 3, 7, 8, 5, 8]
index = [0,1,2,3,4,5,6]

def exchange(lst = list,index = list):
    m = max(lst)
    l = [-1 for i in range(m)]

    for i in range(len(lst)):
        pos = lst[i]
        val = (index[i])
        l[pos-1]=val
    print(l)
        
exchange(lst,index)
# Out:
# [1, -1, 2, -1, 5, -1, 3, 6, -1, -1, -1, 0]

# %%
#-------------------------------------------------try to make ur own ------------------------------

# Write a menu driven program to practice Set functions.
# Write a program to accept names from users and store it in a set.
# Display the following menu:
# print("""1. delete element if exists otherwise
# do not show any errr""")
# print("2. add a elemet")
# print("3. create one more set")
# print("4. union of 2 sets")
# print("4. intersection of 2 sets")
# print("5. difference of 2 sets")
# print("6. convert set into frozenset")
# print("6. exit")


'''
# This part Remaining 
print("6. convert set into frozenset")

'''

import A5_1Q6_module import *

while True: 
    case = int(input("""
                    1. delete element
                    2. add a elemet
                    3. create one more set
                    4. union of 2 sets
                    5. intersection of 2 sets
                    6. difference of 2 sets
                    7. convert set into frozenset
                    8. Print set
                    9. Exit
                    Enter Choice:"""))



    if case == 1:
        x = input("""Enter from which set you want to delete element : 
        1. Set a
        2. Set b
        choice [a/b]: """)
        if x == 'a':
            delset('a')
        elif x == 'b':
            delset('b')
        
    if case == 2:
        addele()

    if case == 3:
        createset()

    if case == 4:
        union()

    if case == 5:
        intersect()

    if case == 6:
        difference()

    if case == 7:
        frozenset()

    if case == 8:
        x = input("""Enter which set you want to print : 
        1. Set a
        2. Set b
        3. Set a and b 
        choice [a / b / ab]: """)
        if x == 'a':
            print(a)
        elif x == 'b':
            print(b)
        elif x == 'ab':
            print(a,b)

    if case == 9:
        print("Exiting......")
        break
# Out:
#   Cell In[11], line 23
#     import A5-1Q6_module import *
#               ^
# SyntaxError: invalid decimal literal

# %%
# Generate a list of lists (NOTE: List should get generated dynamically)
# Accept a number from user and check last digit of the number.
# If it is 1 then add it in the list at 1st position.
# If 0 then it should get added at list in 0th position.
# e.g list should look as follows
# [[10],[51],[52]]
# [[10,30,20,40],[11,31,41,31],[22,32,42]....]
# if user enters 15 then the resultant list should be
# [[10,30,20,40],[11,32,41,31],[22,32,42],[],[],[15]]

l =[]
for i in range(3):
    num = int(input("enter a number"))

    dig = num%10
    print(dig)
    if len(l)>dig:
        (l[dig-1]).append(num)
        pass
    if len(l)<dig:
        r = dig -(len(l))
        for j in range((r)):
            l.append([])
    (l[dig-1]).append(num)

print(l)
# Out:
# 1
# 5
# 9
# [[1], [], [], [], [5], [], [], [], [9]]

# %%
3# Create a list to store strings in a list in following manner list
# [dxz,axz,bat,rat,cat,pat,bbc,bbm,cbm,....] pat axz
# All list with same character at second position should be consecutive.
# If user adds sat, then the resultant list will be:
# [bat,rat,cat,sat,bbc,bbm,cbm,....]
# If user adds pick, then it should be added at
# [bat,rat,cat,bbc,bbm,cbm,pick]
l = ['dxz','axz','bat','rat',"cat","pat",'bbc','bbm','cbm']
while True:
    x = input("enter 3 char. string")
    if x == "-1":
        print(l)
        break
    
    ch = x[1]

    a = list(filter(lambda x :x[1]==ch , l))
    if len(a)!=0:
        index = l.index(a[0])
        l.insert(index,x)
    else:
        l.append(x)

    print(l)
# Out:
# ['dxz', 'axz', 'bat', 'rat', 'cat', 'pat', 'bbc', 'bbm', 'cbm']
