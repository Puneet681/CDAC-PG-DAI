# %% [markdown]
# # __Day 12__

# %% [markdown]
# * ## __Pandas__

# %%
import pandas as pd

# %%
df=pd.read_table('http://bit.ly/chiporders')
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
print(df.columns)
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
df2 = df.rename(columns={'order_id':'new_order_id'})
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
df.rename(columns={'order_id':'new_order_id'},inplace=True)
df
# Out:
#       new_order_id  quantity                              item_name  \
# 0                1         1           Chips and Fresh Tomato Salsa
# 1                1         1                                   Izze
# 2                1         1                       Nantucket Nectar
# 3                1         1  Chips and Tomatillo-Green Chili Salsa
# 4                2         2                           Chicken Bowl
# ...            ...       ...                                    ...
# 4617          1833         1                          Steak Burrito
# 4618          1833         1                          Steak Burrito
# 4619          1834         1                     Chicken Salad Bowl
# 4620          1834         1                     Chicken Salad Bowl
# 4621          1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
#db = pd.read_csv('http://bit.ly/movieusers',sep="|",header=None)
#db.head(10)

# %%
#df.columns = ['col1','col2','col3','col4','col5'] to chnage column names 
#df['col1']

# %%
df.head(10)
# Out:
#    new_order_id  quantity                              item_name  \
# 0             1         1           Chips and Fresh Tomato Salsa
# 1             1         1                                   Izze
# 2             1         1                       Nantucket Nectar
# 3             1         1  Chips and Tomatillo-Green Chili Salsa
# 4             2         2                           Chicken Bowl
# 5             3         1                           Chicken Bowl
# 6             3         1                          Side of Chips
# 7             4         1                          Steak Burrito
# 8             4         1                       Steak Soft Tacos
# 9             5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# ...

# %%
df.info()  # get attribute names and data types
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   new_order_id        4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
print(type(df))  # type is dataframe ,
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
#1d array - data series and multi diamensional - data series

# %%
print(type(df['quantity'])) # type series
# Out:
# <class 'pandas.core.series.Series'>

# %%
print(type(df[['quantity','item_name']])) # type series
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df1 = df[['quantity','item_name']]
df1
# Out:
#       quantity                              item_name
# 0            1           Chips and Fresh Tomato Salsa
# 1            1                                   Izze
# 2            1                       Nantucket Nectar
# 3            1  Chips and Tomatillo-Green Chili Salsa
# 4            2                           Chicken Bowl
# ...        ...                                    ...
# 4617         1                          Steak Burrito
# 4618         1                          Steak Burrito
# 4619         1                     Chicken Salad Bowl
# 4620         1                     Chicken Salad Bowl
# 4621         1                     Chicken Salad Bowl
#
# [4622 rows x 2 columns]

# %%
df.iloc[:,1] # takes integer location as input
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       2
#        ..
# 4617    1
# 4618    1
# 4619    1
# 4620    1
# 4621    1
# Name: quantity, Length: 4622, dtype: int64

# %%
df.iloc[2:7,1:4]
# Out:
#    quantity                              item_name  \
# 2         1                       Nantucket Nectar
# 3         1  Chips and Tomatillo-Green Chili Salsa
# 4         2                           Chicken Bowl
# 5         1                           Chicken Bowl
# 6         1                          Side of Chips
#
#                                   choice_description
# 2                                            [Apple]
# 3                                                NaN
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...
# 5  [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...
# 6                                                NaN

# %%
df.loc[2:7,['new_order_id','item_name']] # takse any location  - integer and text  as input
# Out:
#    new_order_id                              item_name
# 2             1                       Nantucket Nectar
# 3             1  Chips and Tomatillo-Green Chili Salsa
# 4             2                           Chicken Bowl
# 5             3                           Chicken Bowl
# 6             3                          Side of Chips
# 7             4                          Steak Burrito

# %%
df.info() # gives info about datatypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   new_order_id        4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
df.describe() # Gives info about dataframe for numeric attribute values
# Out:
#        new_order_id     quantity
# count   4622.000000  4622.000000
# mean     927.254868     1.075725
# std      528.890796     0.410186
# min        1.000000     1.000000
# 25%      477.250000     1.000000
# 50%      926.000000     1.000000
# 75%     1393.000000     1.000000
# max     1834.000000    15.000000

# %%
df['new_item'] = df['item_price'].map(lambda x:x.replace('$',"0"))
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   new_order_id        4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
#  5   new_item            4622 non-null   object
# dtypes: int64(2), object(4)
# memory usage: 216.8+ KB

# %%
df['new_itemprice'] = df['new_item'].astype('float')
df['discouted_price'] = df['new_itemprice'].map(lambda x:x *0.85) #to  multiply a column with a value
# df['discouted_price'] = df['new_itemprice']*0.85             # another way to  multiply a column with a value
df
# Out:
#       new_order_id  quantity                              item_name  \
# 0                1         1           Chips and Fresh Tomato Salsa
# 1                1         1                                   Izze
# 2                1         1                       Nantucket Nectar
# 3                1         1  Chips and Tomatillo-Green Chili Salsa
# 4                2         2                           Chicken Bowl
# ...            ...       ...                                    ...
# 4617          1833         1                          Steak Burrito
# 4618          1833         1                          Steak Burrito
# 4619          1834         1                     Chicken Salad Bowl
# 4620          1834         1                     Chicken Salad Bowl
# 4621          1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price new_item  \
# ...

# %%
df.pop('new_item')
df
# Out:
#       new_order_id  quantity                              item_name  \
# 0                1         1           Chips and Fresh Tomato Salsa
# 1                1         1                                   Izze
# 2                1         1                       Nantucket Nectar
# 3                1         1  Chips and Tomatillo-Green Chili Salsa
# 4                2         2                           Chicken Bowl
# ...            ...       ...                                    ...
# 4617          1833         1                          Steak Burrito
# 4618          1833         1                          Steak Burrito
# 4619          1834         1                     Chicken Salad Bowl
# 4620          1834         1                     Chicken Salad Bowl
# 4621          1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price  \
# 0                                                   NaN     $2.39
# ...

# %%
#df.drop(['item_price'],axis=1,inplace=True)
df.head(10)
# Out:
#     new_order_id  quantity                              item_name  \
# 0              1         1           Chips and Fresh Tomato Salsa
# 1              1         1                                   Izze
# 3              1         1  Chips and Tomatillo-Green Chili Salsa
# 5              3         1                           Chicken Bowl
# 6              3         1                          Side of Chips
# 7              4         1                          Steak Burrito
# 8              4         1                       Steak Soft Tacos
# 9              5         1                          Steak Burrito
# 11             6         1                   Chicken Crispy Tacos
# 12             6         1                     Chicken Soft Tacos
#
#                                    choice_description  new_itemprice  \
# 0                                                 NaN           2.39
# 1                                        [Clementine]           3.39
# ...

# %%
df.drop([3,5,11],axis=0,inplace=True)
df.head(10)
# Out:
#     new_order_id  quantity                              item_name  \
# 0              1         1           Chips and Fresh Tomato Salsa
# 1              1         1                                   Izze
# 6              3         1                          Side of Chips
# 7              4         1                          Steak Burrito
# 8              4         1                       Steak Soft Tacos
# 9              5         1                          Steak Burrito
# 12             6         1                     Chicken Soft Tacos
# 13             7         1                           Chicken Bowl
# 14             7         1                    Chips and Guacamole
# 15             8         1  Chips and Tomatillo-Green Chili Salsa
#
#                                    choice_description  new_itemprice  \
# 0                                                 NaN           2.39
# 1                                        [Clementine]           3.39
# ...

# %%
df[df['discouted_price']>8] # applying a condition to a specific column
# Out:
#       new_order_id  quantity           item_name  \
# 7                4         1       Steak Burrito
# 13               7         1        Chicken Bowl
# 23              12         1     Chicken Burrito
# 39              19         1       Barbacoa Bowl
# 42              20         1        Chicken Bowl
# ...            ...       ...                 ...
# 4610          1830         1       Steak Burrito
# 4611          1830         1      Veggie Burrito
# 4617          1833         1       Steak Burrito
# 4618          1833         1       Steak Burrito
# 4619          1834         1  Chicken Salad Bowl
#
#                                      choice_description  new_itemprice  \
# 7     [Tomatillo Red Chili Salsa, [Fajita Vegetables...          11.75
# 13    [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...          11.25
# 23    [[Tomatillo-Green Chili Salsa (Medium), Tomati...          10.98
# 39    [Roasted Chili Corn Salsa, [Fajita Vegetables,...          11.75
# ...

# %%
index = df[df['discouted_price']>8].index # to find the index of the value that satisfy the condition
print(index)
df.drop(index , axis = 0,inplace=True) # drops all the index from the DF
df
# Out:
# Int64Index([], dtype='int64')
#       new_order_id  quantity                     item_name  \
# 0                1         1  Chips and Fresh Tomato Salsa
# 1                1         1                          Izze
# 6                3         1                 Side of Chips
# 8                4         1              Steak Soft Tacos
# 9                5         1                 Steak Burrito
# ...            ...       ...                           ...
# 4614          1831         1                 Bottled Water
# 4615          1832         1            Chicken Soft Tacos
# 4616          1832         1           Chips and Guacamole
# 4620          1834         1            Chicken Salad Bowl
# 4621          1834         1            Chicken Salad Bowl
#
#                                      choice_description  new_itemprice  \
# 0                                                   NaN           2.39
# 1                                          [Clementine]           3.39
# ...

# %%
print(df.shape)
# Out:
# (3488, 6)

# %%
import pandas as pd
dummy_data1 = {
        'id': ['1', '2', '3', '4', '5'],
        'Feature1': ['A', 'C', 'E', 'G', 'I'],
        'Feature2': ['B', 'D', 'F', 'H', 'J']}

df1 = pd.DataFrame(dummy_data1, columns = ['id', 'Feature1', 'Feature2']) 

df1
# Out:
#   id Feature1 Feature2
# 0  1        A        B
# 1  2        C        D
# 2  3        E        F
# 3  4        G        H
# 4  5        I        J

# %%
dummy_data2 = {
        'id': ['1', '2', '6', '7', '8'],
        'Feature1': ['K', 'M', 'O', 'Q', 'S'],
        'Feature2': ['L', 'N', 'P', 'R', 'T']}
df2 = pd.DataFrame(dummy_data2, columns = ['id', 'Feature1', 'Feature2'])

df2
# Out:
#   id Feature1 Feature2
# 0  1        K        L
# 1  2        M        N
# 2  6        O        P
# 3  7        Q        R
# 4  8        S        T

# %%
df1['city']='Pune'
df2['city']="mumbai"

df3=pd.concat([df1,df2],ignore_index=True)

df3
# Out:
#   id Feature1 Feature2    city
# 0  1        A        B    Pune
# 1  2        C        D    Pune
# 2  3        E        F    Pune
# 3  4        G        H    Pune
# 4  5        I        J    Pune
# 5  1        K        L  mumbai
# 6  2        M        N  mumbai
# 7  6        O        P  mumbai
# 8  7        Q        R  mumbai
# 9  8        S        T  mumbai

# %%
print(df3.loc[0])
dummy_data3 = {
        'id': ['1', '2', '3', '4', '5', '7', '8', '9', '10', '11'],
        'Feature3': [12, 13, 14, 15, 16, 17, 15, 12, 13, 23]}
df4 = pd.DataFrame(dummy_data3, columns = ['id', 'Feature3'])
df5=pd.merge(df3,df4,on="id",how="outer") # on = basis on how = left join , right join , outer join
df5
# Out:
# id             1
# Feature1       A
# Feature2       B
# city        Pune
# Name: 0, dtype: object
#     id Feature1 Feature2    city  Feature3
# 0    1        A        B    Pune      12.0
# 1    1        K        L  mumbai      12.0
# 2    2        C        D    Pune      13.0
# 3    2        M        N  mumbai      13.0
# 4    3        E        F    Pune      14.0
# 5    4        G        H    Pune      15.0
# 6    5        I        J    Pune      16.0
# 7    6        O        P  mumbai       NaN
# 8    7        Q        R  mumbai      17.0
# 9    8        S        T  mumbai      15.0
# 10   9      NaN      NaN     NaN      12.0
# 11  10      NaN      NaN     NaN      13.0
# 12  11      NaN      NaN     NaN      23.0

# %%
df5.loc[len(df5.index)]=['12','S','X','Pune','15']
d={'id':12,'Feature1':'S1','Feature2':'x2','city':'YYY','Feature3':'45'}
df5=df5.append(d,ignore_index=True)
df5
# Out:
# /tmp/ipykernel_70277/1665109456.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df5=df5.append(d,ignore_index=True)
#     id Feature1 Feature2    city Feature3
# 0    1        A        B    Pune     12.0
# 1    1        K        L  mumbai     12.0
# 2    2        C        D    Pune     13.0
# 3    2        M        N  mumbai     13.0
# 4    3        E        F    Pune     14.0
# 5    4        G        H    Pune     15.0
# 6    5        I        J    Pune     16.0
# 7    6        O        P  mumbai      NaN
# 8    7        Q        R  mumbai     17.0
# 9    8        S        T  mumbai     15.0
# 10   9      NaN      NaN     NaN     12.0
# 11  10      NaN      NaN     NaN     13.0
# 12  11      NaN      NaN     NaN     23.0
# 13  12        S        X    Pune       15
# 14  12       S1       x2     YYY       45
