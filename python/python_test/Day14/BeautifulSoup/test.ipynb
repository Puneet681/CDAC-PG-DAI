# %%
import requests
from bs4 import BeautifulSoup
import re
url = 'https://www.imdb.com/search/title/?release_date=2022-01-01,2023-12-01'

response = requests.get(url)
# print(response.text)


html_soup = BeautifulSoup(response.text,'html.parser')
type(html_soup)
# print(html_soup)

movie_containers = html_soup.find_all('div' , class_ = 'lister-item mode-advanced')

# print(type(movie_containers))
# print(len(movie_containers))

#frist_movie = movie_containers[0]
# print(frist_movie)

# h3 = frist_movie.find("a")
# h3[1]
# print(frist_movie.h3)
# print(frist_movie.h3.a)
# print(frist_movie.h3.a.text)

#y = frist_movie.find('span' , class_ = 'lister-item-year text-muted unbold')
# print(y)
# print(y.text)


#r = frist_movie.find('div' , class_ = 'inline-block ratings-imdb-rating')
# print(r.strong)
# print(r.strong.text)


name = []
rating =  []
years = []

for movie in movie_containers:
    try:
        name.append(movie.h3.a.text)
    except:
        name.append('nan')
    try:
        r = movie.find('div' , class_ = 'inline-block ratings-imdb-rating')
        rating.append(r.strong.text)
    except:    
        rating.append('nan')
    try:
        y = movie.find('span' , class_ = 'lister-item-year text-muted unbold')
        years.append(y.text)
    except:        
        years.append('nan')
# print(name,years,rating)

data = {'name':name , 'year':years,'rating':rating}
# print(data)

import pandas as pd 

db = pd.DataFrame(data)
db
# Out:
#                                                  name         year rating
# 0                                              Ahsoka     (2023– )    8.0
# 1                                           One Piece     (2023– )    8.4
# 2                                A Haunting in Venice       (2023)    6.8
# 3                                              Barbie   (I) (2023)    7.1
# 4                                           Elemental       (2023)    7.0
# 5                                          Talk to Me   (I) (2022)    7.2
# 6                                         Expend4bles       (2023)    5.2
# 7                                          Wilderness       (2023)    6.3
# 8        The Continental: From the World of John Wick       (2023)    7.5
# 9                                 Love at First Sight   (I) (2023)    6.9
# 10                                              Jawan       (2023)    7.6
# 11                                        Oppenheimer       (2023)    8.6
# 12                                        Blue Beetle       (2023)    6.3
# 13                                        Liebes Kind       (2023)    7.4
# 14                               A Million Miles Away       (2023)    7.4
# 15                                 The Little Mermaid   (I) (2023)    7.2
# 16                                         The Nun II       (2023)    5.9
# 17                                           The Bear     (2022– )    8.6
# 18                         Killers of the Flower Moon       (2023)    nan
# 19                               No One Will Save You       (2023)    6.4
# 20                      The Walking Dead: Daryl Dixon     (2023– )    8.1
# 21  The Hunger Games: The Ballad of Songbirds and ...       (2023)    nan
# 22                               Special Ops: Lioness     (2023– )    7.7
# 23                                        Retribution   (I) (2023)    5.3
# 24                                    The Equalizer 3       (2023)    7.1
# 25                                        The Creator       (2023)    7.9
# 26        Teenage Mutant Ninja Turtles: Mutant Mayhem       (2023)    7.3
# 27       Winning Time: The Rise of the Lakers Dynasty  (2022–2023)    8.3
# 28                                     Dream Scenario       (2023)    7.8
# 29                                       Theater Camp       (2023)    7.1
# 30                             Harlan Coben's Shelter     (2023– )    6.6
# 31                                Who Is Erin Carter?       (2023)    6.5
# 32                                   No Hard Feelings       (2023)    6.4
# 33                                         Dumb Money       (2023)    7.1
# 34           You Are So Not Invited to My Bat Mitzvah       (2023)    6.0
# 35                                            Bottoms       (2023)    7.2
# 36                                              Saw X       (2023)    9.0
# 37                                        Poor Things       (2023)    8.1
# 38                                                  X  (II) (2022)    6.6
# 39                               John Wick: Chapter 4       (2023)    7.8
# 40                Spider-Man: Across the Spider-Verse       (2023)    8.7
# 41              Indiana Jones and the Dial of Destiny       (2023)    6.7
# 42                                           El Conde       (2023)    6.5
# 43                            Five Nights at Freddy's       (2023)    nan
# 44                                         Jaane Jaan       (2023)    7.1
# 45                                   Sound of Freedom       (2023)    7.8
# 46                                All of Us Strangers       (2023)    5.9
# 47                     The Fall of the House of Usher     (2023– )    nan
# 48                                             Fast X       (2023)    5.8
# 49                                          The Flash   (I) (2023)    6.8

# %%
len(name)
# Out:
# 50

# %%
len(years)
# Out:
# 50

# %%
len(rating)
# Out:
# 50
