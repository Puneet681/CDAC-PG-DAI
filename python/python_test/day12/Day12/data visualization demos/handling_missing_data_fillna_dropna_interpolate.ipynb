# %% [markdown]
# ## <font color="maroon"><h4 align="center">Handling Missing Data - fillna, interpolate, dropna</font>

# %%
#data cleaning/data munging
import pandas as pd
df = pd.read_csv("weather_data_missing.csv")
#df = pd.read_csv("weather_data_missing.csv",index_col='day',parse_dates=['day'])
#df = pd.read_csv("weather_data_missing.csv",skiprows =3,parse_dates=['day'])
#type(df['day'])
df
# Out:
#           day  temperature windspeed   event
# 0  01-01-2017         32.0         6    Rain
# 1  01-04-2017          NaN         9   Sunny
# 2  01-05-2017         28.0      Snow     NaN
# 3  01-06-2017          NaN         7     NaN
# 4  01-07-2017         32.0       NaN    Rain
# 5  01-08-2017          NaN       NaN   Sunny
# 6  01-09-2017          NaN       NaN     NaN
# 7  01-10-2017         34.0         8  Cloudy
# 8  01-11-2017         40.0        12   Sunny
# 9         NaN          NaN       8.4     NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          9 non-null      object
#  1   temperature  5 non-null      float64
#  2   windspeed    7 non-null      object
#  3   event        6 non-null      object
# dtypes: float64(1), object(3)
# memory usage: 452.0+ bytes

# %%
#df.set_index('day',inplace=True)
#df.loc["01-07-2017"]
df
df.info()
#df.isnull()
#import seaborn as sns
#sns.heatmap(df.isnull(),yticklabels=False,cmap="viridis")
#sns.color_palette("rocket", as_cmap=True)
#sns.heatmap(df.isnull(),yticklabels=False,cmap="YlGnBu")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          9 non-null      object
#  1   temperature  5 non-null      float64
#  2   windspeed    7 non-null      object
#  3   event        6 non-null      object
# dtypes: float64(1), object(3)
# memory usage: 452.0+ bytes

# %%
#df.reset_index('day',inplace=True)
df.reset_index(inplace=True)
df
#df.info()
# Out:
#    index         day  temperature windspeed   event
# 0      0  01-01-2017         32.0         6    Rain
# 1      1  01-04-2017          NaN         9   Sunny
# 2      2  01-05-2017         28.0      Snow     NaN
# 3      3  01-06-2017          NaN         7     NaN
# 4      4  01-07-2017         32.0       NaN    Rain
# 5      5  01-08-2017          NaN       NaN   Sunny
# 6      6  01-09-2017          NaN       NaN     NaN
# 7      7  01-10-2017         34.0         8  Cloudy
# 8      8  01-11-2017         40.0        12   Sunny
# 9      9         NaN          NaN       8.4     NaN

# %% [markdown]
# ## <font color="blue">fillna</font>

# %% [markdown]
# <font color="purple">**Fill all NaN with one specific value**</font>

# %%
#thresh= 2 Require that minimum 2 non-NA values.
#new_df=df.dropna(thresh=2)
new_df = df.fillna(0)
new_df
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   index        10 non-null     int64
#  1   day          10 non-null     object
#  2   temperature  10 non-null     float64
#  3   windspeed    10 non-null     object
#  4   event        10 non-null     object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 532.0+ bytes

# %% [markdown]
# <font color="purple">**Fill na using column names and dict**</font>

# %%
new_df = df.fillna({
        'temperature': 0,
        'windspeed': 1,
        'event': 'No Event'
    })
new_df
# Out:
#    index         day  temperature windspeed     event
# 0      0  01-01-2017         32.0         6      Rain
# 1      1  01-04-2017          0.0         9     Sunny
# 2      2  01-05-2017         28.0      Snow  No Event
# 3      3  01-06-2017          0.0         7  No Event
# 4      4  01-07-2017         32.0         1      Rain
# 5      5  01-08-2017          0.0         1     Sunny
# 6      6  01-09-2017          0.0         1  No Event
# 7      7  01-10-2017         34.0         8    Cloudy
# 8      8  01-11-2017         40.0        12     Sunny
# 9      9         NaN          0.0       8.4  No Event

# %%
new_df=df.copy()
new_df['temperature'].fillna(new_df['temperature'].mean(),inplace=True)
new_df['windspeed'].fillna(new_df['windspeed'].mean(),inplace=True)
new_df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/dai/Desktop/Python/Day12/data visualization demos/handling_missing_data_fillna_dropna_interpolate.ipynb Cell 12 line 3
#       <a href='vscode-notebook-cell:/home/dai/Desktop/Python/Day12/data%20visualization%20demos/handling_missing_data_fillna_dropna_interpolate.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> new_df=df.copy()
#       <a href='vscode-notebook-cell:/home/dai/Desktop/Python/Day12/data%20visualization%20demos/handling_missing_data_fillna_dropna_interpolate.ipynb#X13sZmlsZQ%3D%3D?line=1'>2</a> new_df['temperature'].fillna(new_df['temperature'].mean(),inplace=True)
# ----> <a href='vscode-notebook-cell:/home/dai/Desktop/Python/Day12/data%20visualization%20demos/handling_missing_data_fillna_dropna_interpolate.ipynb#X13sZmlsZQ%3D%3D?line=2'>3</a> new_df['windspeed'].fillna(new_df['windspeed'].mean(),inplace=True)
#       <a href='vscode-notebook-cell:/home/dai/Desktop/Python/Day12/data%20visualization%20demos/handling_missing_data_fillna_dropna_interpolate.ipynb#X13sZmlsZQ%3D%3D?line=3'>4</a> new_df
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:11847, in NDFrame._add_numeric_operations.<locals>.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11829 @doc(
#   11830     _num_doc,
#   11831     desc="Return the mean of the values over the requested axis.",
#    (...)
#   11845     **kwargs,
#   11846 ):
# > 11847     return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:11401, in NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11393 def mean(
#   11394     self,
#   11395     axis: Axis | None | lib.NoDefault = lib.no_default,
#    (...)
#   11399     **kwargs,
#   11400 ) -> Series | float:
# > 11401     return self._stat_function(
#   11402         "mean", nanops.nanmean, axis, skipna, level, numeric_only, **kwargs
#   11403     )
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:11353, in NDFrame._stat_function(self, name, func, axis, skipna, level, numeric_only, **kwargs)
#   11343     warnings.warn(
#   11344         "Using the level keyword in DataFrame and Series aggregations is "
#   11345         "deprecated and will be removed in a future version. Use groupby "
#    (...)
#   11348         stacklevel=find_stack_level(),
#   11349     )
#   11350     return self._agg_by_level(
#   11351         name, axis=axis, level=level, skipna=skipna, numeric_only=numeric_only
#   11352     )
# > 11353 return self._reduce(
#   11354     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11355 )
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/series.py:4816, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4812     raise NotImplementedError(
#    4813         f"Series.{name} does not implement {kwd_name}."
#    4814     )
#    4815 with np.errstate(all="ignore"):
# -> 4816     return op(delegate, skipna=skipna, **kwds)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/nanops.py:93, in disallow.__call__.<locals>._f(*args, **kwargs)
#      91 try:
#      92     with np.errstate(invalid="ignore"):
# ---> 93         return f(*args, **kwargs)
#      94 except ValueError as e:
#      95     # we want to transform an object array
#      96     # ValueError message to the more typical TypeError
#      97     # e.g. this is normally a disallowed function on
#      98     # object arrays that contain strings
#      99     if is_object_dtype(args[0]):
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/nanops.py:155, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     153         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     154 else:
# --> 155     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     157 return result
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/nanops.py:418, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     415 if datetimelike and mask is None:
#     416     mask = isna(values)
# --> 418 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     420 if datetimelike:
#     421     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/nanops.py:706, in nanmean(values, axis, skipna, mask)
#     703     dtype_count = dtype
#     705 count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 706 the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     708 if axis is not None and getattr(the_sum, "ndim", False):
#     709     count = cast(np.ndarray, count)
#
# File ~/.local/lib/python3.11/site-packages/numpy/core/_methods.py:49, in _sum(a, axis, dtype, out, keepdims, initial, where)
#      47 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      48          initial=_NoValue, where=True):
# ---> 49     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# <font color="purple">**Use method to determine how to fill na values**</font>

# %%
df
new_df = df.fillna(method="ffill") #forward fill
new_df
# Out:
#           day  temperature  windspeed   event
# 0  01-01-2017         32.0        6.0    Rain
# 1  01-04-2017         32.0        9.0   Sunny
# 2  01-05-2017         28.0        9.0    Snow
# 3  01-06-2017         28.0        7.0    Snow
# 4  01-07-2017         32.0        7.0    Rain
# 5  01-08-2017         32.0        7.0   Sunny
# 6  01-09-2017         32.0        7.0   Sunny
# 7  01-10-2017         34.0        8.0  Cloudy
# 8  01-11-2017         40.0       12.0   Sunny

# %%
#ffill on specific column
new_df=df.loc[:,'windspeed'].ffill()
new_df

# %%
new_df = df.fillna(method="bfill")
new_df
# Out:
#           day  temperature  windspeed   event
# 0  01-01-2017         32.0        6.0    Rain
# 1  01-04-2017         28.0        9.0   Sunny
# 2  01-05-2017         28.0        7.0    Snow
# 3  01-06-2017         32.0        7.0    Rain
# 4  01-07-2017         32.0        8.0    Rain
# 5  01-08-2017         34.0        8.0   Sunny
# 6  01-09-2017         34.0        8.0  Cloudy
# 7  01-10-2017         34.0        8.0  Cloudy
# 8  01-11-2017         40.0       12.0   Sunny

# %% [markdown]
# <font color="purple">**Use of axis**</font>

# %%
new_df = df.fillna(method="bfill", axis="columns") # axis is either "index" or "columns"
new_df

# %% [markdown]
# <font color="purple">**limit parameter**</font>

# %%
#limit will specify how many values should get replace
new_df = df.fillna(method="ffill",limit=2)
#new_df = df.fillna(method="ffill")
new_df
# Out:
#           day  temperature  windspeed   event
# 0  01-01-2017         32.0        6.0    Rain
# 1  01-04-2017         32.0        9.0   Sunny
# 2  01-05-2017         28.0        9.0    Snow
# 3  01-06-2017         28.0        7.0    Snow
# 4  01-07-2017         32.0        7.0    Rain
# 5  01-08-2017         32.0        7.0   Sunny
# 6  01-09-2017         32.0        NaN   Sunny
# 7  01-10-2017         34.0        8.0  Cloudy
# 8  01-11-2017         40.0       12.0   Sunny

# %% [markdown]
# ### <font color="blue">interpolate</font>

# %%
new_df = df.interpolate()
new_df
# Out:
#           day  temperature  windspeed   event
# 0  01-01-2017    32.000000       6.00    Rain
# 1  01-04-2017    30.000000       9.00   Sunny
# 2  01-05-2017    28.000000       8.00    Snow
# 3  01-06-2017    30.000000       7.00     NaN
# 4  01-07-2017    32.000000       7.25    Rain
# 5  01-08-2017    32.666667       7.50   Sunny
# 6  01-09-2017    33.333333       7.75     NaN
# 7  01-10-2017    34.000000       8.00  Cloudy
# 8  01-11-2017    40.000000      12.00   Sunny

# %%
new_df = df.interpolate() 
new_df

# %%
df['temperature f']=df['temperature'].map(lambda x:x+10)
df
# Out:
#           day  temperature  windspeed   event  temperature f
# 0  01-01-2017         32.0        6.0    Rain           42.0
# 1  01-04-2017          NaN        9.0   Sunny            NaN
# 2  01-05-2017         28.0        NaN    Snow           38.0
# 3  01-06-2017          NaN        7.0     NaN            NaN
# 4  01-07-2017         32.0        NaN    Rain           42.0
# 5  01-08-2017          NaN        NaN   Sunny            NaN
# 6  01-09-2017          NaN        NaN     NaN            NaN
# 7  01-10-2017         34.0        8.0  Cloudy           44.0
# 8  01-11-2017         40.0       12.0   Sunny           50.0

# %%
def myconvert(num):
    if num<30:
        return num+10
    elif num>=30 and num<35:
        return num+20
    else:
        return num+30
    
df['temperature f']=df['temperature'].apply(myconvert) 
df

# %% [markdown]
# **Notice that in above temperature on 2017-01-04 is 29 instead of 30 (in plain linear interpolate)**

# %% [markdown]
# **There are many other methods for interpolation such as quadratic, piecewise_polynomial, cubic etc.
# Just google "dataframe interpolate" to see complete documentation**

# %% [markdown]
# ### <font color="blue">dropna</font>

# %%
new_df = df.dropna()    
new_df

# %%
new_df =df .dropna(how='all')
new_df

# %%
new_df = df.dropna(thresh=2)
new_df
#less that 2 not null values

# %% [markdown]
# ### <font color="blue">Inserting Missing Dates</font>

# %%
dt = pd.date_range("01-01-2017","01-11-2017")
idx = pd.DatetimeIndex(dt)
df.reindex(idx)
