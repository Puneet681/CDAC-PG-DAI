# %% [markdown]
# ## Question 1

# %% [markdown]
# * 1. Create two CSV file with three columns viz. Tom, Brick, Harry with index ‘True’ and ‘False’.
# Each column must contain at least ten values each as a combination of datatypes.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.DataFrame({"Tom": [1,2,3,'Nan',5435,5345,32,32,np.nan,(342.42340,)],"Brick":['1',2,4,72,23,332,32,32,54,13],"Harry":['dsa',234,'dgd',243,42,243,4,3,np.nan,423.243]})
df
# Out:
#            Tom Brick    Harry
# 0            1     1      dsa
# 1            2     2      234
# 2            3     4      dgd
# 3          Nan    72      243
# 4         5435    23       42
# 5         5345   332      243
# 6           32    32        4
# 7           32    32        3
# 8          NaN    54      NaN
# 9  (342.4234,)    13  423.243

# %%
f = open('Ass2Q1_1.csv','w')
f.close()

# %%
df.to_csv('Ass2Q1_1.csv',index=True)

# %%
f = open('Ass2Q1_2.csv','w')
f.close()

# %%
df.to_csv('Ass2Q1_2.csv',index=False)

# %% [markdown]
# * 2. Create a data frame with at least 5 columns and 10 rows. There must be some missing
# values in it. If the integer column contains missing values replace it with some statistical
# approach. Also, if there is any missing values in String column, drop the rows using some
# looping function.

# %%
a = np.random.randint(0,10,size=(10,5)).astype(int)
a = pd.DataFrame(a)
a
a.replace({0 : np.nan},inplace=True)
a[4] = a[4].astype(str)
a[4].replace({'nan' : np.nan},inplace=True)
a
# Out:
#      0  1    2  3    4
# 0  2.0  1  7.0  6  NaN
# 1  3.0  2  5.0  9  3.0
# 2  2.0  4  2.0  9  6.0
# 3  2.0  3  7.0  8  5.0
# 4  1.0  9  1.0  9  NaN
# 5  4.0  8  NaN  1  6.0
# 6  2.0  6  8.0  9  7.0
# 7  5.0  1  7.0  3  9.0
# 8  NaN  7  2.0  7  8.0
# 9  9.0  4  8.0  5  5.0

# %%
~a.isna()
# Out:
#        0     1      2     3      4
# 0   True  True   True  True  False
# 1   True  True   True  True   True
# 2   True  True   True  True   True
# 3   True  True   True  True   True
# 4   True  True   True  True  False
# 5   True  True  False  True   True
# 6   True  True   True  True   True
# 7   True  True   True  True   True
# 8  False  True   True  True   True
# 9   True  True   True  True   True

# %%
a = a[~(a[4].isna())]
a
# Out:
#      0  1    2  3    4
# 1  3.0  2  5.0  9  3.0
# 2  2.0  4  2.0  9  6.0
# 3  2.0  3  7.0  8  5.0
# 5  4.0  8  NaN  1  6.0
# 6  2.0  6  8.0  9  7.0
# 7  5.0  1  7.0  3  9.0
# 8  NaN  7  2.0  7  8.0
# 9  9.0  4  8.0  5  5.0

# %%
a[0] = a[0].fillna(a[0].mean())
a[0] = a[0].round()
a[1] = a[1].fillna(a[1].mean())
a[1] = a[1].round()
a[2] = a[2].fillna(a[3].mean())
a[2] = a[2].round()
a[3] = a[3].fillna(a[3].mean())
a[3] = a[3].round()
a
# Out:
# /tmp/ipykernel_49532/598748567.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a[0] = a[0].fillna(a[0].mean())
# /tmp/ipykernel_49532/598748567.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a[0] = a[0].round()
# /tmp/ipykernel_49532/598748567.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %% [markdown]
# * 3. Create a data frame with at least 5 columns and 10 rows. Each column must contain only
# integer elements only. Column names must be Abilash, Ankit, Ashok, Asif, Anjaan. Now
# apply a function where we want to club together the data based on any row or column.
# Group the series using a mapper or by a series of columns.

# %%
a = np.random.randint(0,10,size=(10,5)).astype(int)
a = pd.DataFrame(a,columns=['Abilash', 'Ankit', 'Ashok', 'Asif', 'Anjaan'])
a

s1 = pd.DataFrame([np.arange(5)])
s1.columns = ['Abilash', 'Ankit', 'Ashok', 'Asif', 'Anjaan']
s1
# Out:
#    Abilash  Ankit  Ashok  Asif  Anjaan
# 0        0      1      2     3       4

# %%
concat_by_row = pd.concat([a,s1])
concat_by_row
# Out:
#    Abilash  Ankit  Ashok  Asif  Anjaan
# 0        9      2      6     0       0
# 1        4      6      1     6       5
# 2        6      0      4     7       4
# 3        3      4      2     3       5
# 4        7      7      8     6       5
# 5        0      5      3     3       2
# 6        1      0      7     8       4
# 7        4      3      7     4       6
# 8        1      5      4     7       1
# 9        1      5      7     0       5
# 0        0      1      2     3       4

# %%
new_col = pd.DataFrame(np.random.randint(10,51,size=(10,1)),columns=['new_col'])

a = pd.concat([a,new_col],axis=1)
a
# Out:
#    Abilash  Ankit  Ashok  Asif  Anjaan  new_col
# 0        9      2      6     0       0       29
# 1        4      6      1     6       5       28
# 2        6      0      4     7       4       32
# 3        3      4      2     3       5       13
# 4        7      7      8     6       5       39
# 5        0      5      3     3       2       32
# 6        1      0      7     8       4       42
# 7        4      3      7     4       6       41
# 8        1      5      4     7       1       44
# 9        1      5      7     0       5       26

# %%
new_col2 = pd.DataFrame(np.random.randint(10,51,size=(10,1)),columns=['new_col2'])

a.merge(new_col2,on=new_col2['new_col2'])
# Out:
#    key_0  Abilash  Ankit  Ashok  Asif  Anjaan  new_col  new_col2
# 0     22        9      2      6     0       0       29        22
# 1     11        4      6      1     6       5       28        11
# 2     13        6      0      4     7       4       32        13
# 3     48        3      4      2     3       5       13        48
# 4     14        7      7      8     6       5       39        14
# 5     18        0      5      3     3       2       32        18
# 6     16        1      0      7     8       4       42        16
# 7     50        4      3      7     4       6       41        50
# 8     20        1      5      4     7       1       44        20
# 9     19        1      5      7     0       5       26        19

# %% [markdown]
# * 4. Read the CountryDataIND.csv file and perform statistical operation on the same about the
# dataset. Look for any missing data if any.

# %%
df = pd.read_csv('CountryDataIND.csv')
df.isna().sum()
# Out:
# Series Code               0
# Frequency                 0
# Series                    0
# Units of measurement      0
# Location                  0
# Age group                 0
# Sex                       0
# Reference Area            0
# Source type               0
# Time period               0
# Observation Value         0
# Unit multiplier           0
# Nature of data points     0
# Time period details       0
# Source details            6
# Footnotes                29
# dtype: int64

# %%
print(df.isna().sum())
df.columns
# Out:
# Series Code               0
# Frequency                 0
# Series                    0
# Units of measurement      0
# Location                  0
# Age group                 0
# Sex                       0
# Reference Area            0
# Source type               0
# Time period               0
# Observation Value         0
# Unit multiplier           0
# Nature of data points     0
# Time period details       0
# Source details            6
# Footnotes                29
# dtype: int64
# Index(['Series Code', 'Frequency', 'Series', 'Units of measurement',
#        'Location', 'Age group', 'Sex', 'Reference Area', 'Source type',
#        'Time period', 'Observation Value', 'Unit multiplier',
#        'Nature of data points', 'Time period details', 'Source details',
#        'Footnotes'],
#       dtype='object')

# %%
df.drop(columns='Footnotes',inplace=True)

# %%
df.columns
# Out:
# Index(['Series Code', 'Frequency', 'Series', 'Units of measurement',
#        'Location', 'Age group', 'Sex', 'Reference Area', 'Source type',
#        'Time period', 'Observation Value', 'Unit multiplier',
#        'Nature of data points', 'Time period details', 'Source details'],
#       dtype='object')

# %%
df['Source details'].ffill(inplace=True)
df['Source details'].isna().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# Series Code              0
# Frequency                0
# Series                   0
# Units of measurement     0
# Location                 0
# Age group                0
# Sex                      0
# Reference Area           0
# Source type              0
# Time period              0
# Observation Value        0
# Unit multiplier          0
# Nature of data points    0
# Time period details      0
# Source details           0
# dtype: int64

# %% [markdown]
# * 5. Plot a histogram by keeping the bin size to 10 for the column name = ‘Observation Value’.
# Also Plot a scatter plot between ‘observation Value’ and ‘Time Period’

# %%
sns.histplot(df['Observation Value'],color='red',kde=True)
# Out:
# <Axes: xlabel='Observation Value', ylabel='Count'>

# %%
plt.scatter(x = df['Observation Value'] , y = df['Time period'])

# %% [markdown]
# ## Question 2

# %% [markdown]
# Suppose you have landed to a job and the first task you’ve assigned to prepare a report which
# includes the following:
# 1. Player Count
#     * Total Number of Players
# 2. Purchasing Analysis (Total)
#     * Number of Unique Items
#     * Average Purchase Price
#     * Total Number of Purchases
#     * Total Revenue
# 3. Gender Demographics
#     * Percentage and Count of Male Players
#     * Percentage and Count of Female Players
#     * Percentage and Count of Other / Non-Disclosed
# 4. Purchasing Analysis (Gender)
#     * The below each broken by gender
#     * Purchase Count
#     * Average Purchase Price
#     * Total Purchase Value
#     * Average Purchase Total per Person by Gender
#
# 5. Age Demographics
#     * The below each broken into bins of 4 years (i.e. <10, 10-14, 15-19, etc.)
#     * Purchase Count
#     * Average Purchase Price
#     * Total Purchase Value
#     * Average Purchase Total per Person by Age Group
#
# 6. Top Spenders
#     * Identify the the top 5 spenders in the game by total purchase value, then list (in a
#     table):
#
#     * SN
#     * Purchase Count
#     * Average Purchase Price
#     * Total Purchase Value
#
# 7. Most Popular Items
#     * Identify the 5 most popular items by purchase count, then list (in a table):
#     * Item ID
#     * Item Name
#     * Purchase Count
#     * Item Price
#     * Total Purchase Value
#
# 8. Most Profitable Items
#     * the 5 most profitable items by total purchase value, then list (in a table):
#     * Item ID
#     * Item Name
#     * Purchase Count
#     * Item Price
#     * Total Purchase Value

# %%
df = pd.read_csv('purchase_data.csv')

# %%
print(f"The total count of palyers is:- {df['SN'].nunique()}")
# Out:
# The total count of palyers is:- 576

# %%
print(f"total numbers of Items {df['Item Name'].nunique()}")
# Out:
# total numbers of Items 179

# %%
df2 = df[['Item Name','Price']]
grp = df2.groupby('Item Name').mean()
print("Avrage sale for each Item is as follows:-")
grp
# Out:
# Avrage sale for each Item is as follows:-
#                                  Price
# Item Name
# Abyssal Shard                     2.67
# Aetherius, Boon of the Blessed    3.39
# Agatha                            3.08
# Alpha                             2.07
# Alpha, Oath of Zeal               4.05
# ...                                ...
# Wolf                              3.54
# Wolf, Promise of the Moonwalker   4.48
# Worldbreaker                      2.60
# Yearning Crusher                  4.18
# Yearning Mageblade                3.82
#
# [179 rows x 1 columns]

# %%
print(f"Total number of Sale is {df['Item Name'].count()}")
# Out:
# Total number of Sale is 780

# %%
print(f"Total Ravenue is :- {df2['Price'].sum()}")
# Out:
# Total Ravenue is :- 2379.77

# %%
df['Gender'].unique()
# Out:
# array(['Male', 'Other / Non-Disclosed', 'Female'], dtype=object)

# %%
total = df['Gender'].count()
cond = df['Gender'] == 'Male'
Male_count = df[cond]['Gender'].count()
M_per = (Male_count/total)*100
cond = df['Gender'] == 'Female'
Female_count = df[cond]['Gender'].count()
F_per = (Female_count/total)*100

O_count = total-(Male_count+Female_count)
O_per =  100 - (M_per+F_per)

print(f"male count = {Male_count}, male percetage = {M_per}")
print(f"Female count = {Female_count}, Female percentage ={F_per}")
print(f"Other Count = {O_count}, Other percentage = {O_per}")
# Out:
# male count = 652, male percetage = 83.58974358974359
# Female count = 113, Female percentage =14.487179487179489
# Other Count = 15, Other percentage = 1.9230769230769198

# %%
total = df['Gender'].count()
count = df.Gender.value_counts()
ind= count.index

for i in range(len(count)):
    print(f"{ind[i]} count : {count[i]} , {ind[i]} Percentage : {(count[i]/total)*100}")
# Out:
# Male count : 652 , Male Percentage : 83.58974358974359
# Female count : 113 , Female Percentage : 14.487179487179489
# Other / Non-Disclosed count : 15 , Other / Non-Disclosed Percentage : 1.9230769230769231

# %%
df2 = df[['Gender','Price']]
df2.groupby('Gender').mean()['Price']
# Out:
# Gender
# Female                   3.203009
# Male                     3.017853
# Other / Non-Disclosed    3.346000
# Name: Price, dtype: float64

# %%
df3 = df2.groupby('Gender').count()
df3["Purchase Count"] = df3['Price']
df3['Avrage_Price'] = df2.groupby('Gender').mean()['Price']
df3['Total_Price'] = df2.groupby('Gender').sum()['Price']
df3
# Out:
#                        Price  Purchase Count  Avrage_Price  Total_Price
# Gender
# Female                   113             113      3.203009       361.94
# Male                     652             652      3.017853      1967.64
# Other / Non-Disclosed     15              15      3.346000        50.19

# %%
df.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %%
df2 = df[['Age','Price']]
df3 = df2.sort_values('Age')
df4 = df3.groupby('Age').mean()
df4 = df4.reset_index()

# %%
dict1 = {'Age_range':[],'Avrage':[]}
for i in range(0,len(df4),4):
    key = f"{df4['Age'].iloc[i]} <Age< {df4['Age'].iloc[i]+4}"
    val = df4['Price'].iloc[i:i+4].mean()
    dict1["Age_range"].append(key)
    dict1['Avrage'].append(val)

data = pd.DataFrame(dict1)
data
# Out:
#      Age_range    Avrage
# 0   7 <Age< 11  3.370590
# 1  11 <Age< 15  2.783780
# 2  15 <Age< 19  3.032614
# 3  19 <Age< 23  3.021930
# 4  23 <Age< 27  3.026314
# 5  27 <Age< 31  2.568750
# 6  31 <Age< 35  2.804320
# 7  35 <Age< 39  3.421790
# 8  39 <Age< 43  3.467917
# 9  43 <Age< 47  2.793333

# %%
df2 = df[['Age','Price']]
df3 = df2.sort_values('Age')
df4 = df3.groupby('Age').count()
df4 = df4.reset_index()

dict1 = {'Age_range':[],'Avrage':[]}
for i in range(0,len(df4),4):
    key = f"{df4['Age'].iloc[i]} <Age< {df4['Age'].iloc[i]+4}"
    val = df4['Price'].iloc[i:i+4].sum()
    dict1["Age_range"].append(key)
    dict1['Avrage'].append(val)

data = pd.DataFrame(dict1)
data
# Out:
#      Age_range  Avrage
# 0   7 <Age< 11      32
# 1  11 <Age< 15      19
# 2  15 <Age< 19     113
# 3  19 <Age< 23     254
# 4  23 <Age< 27     207
# 5  27 <Age< 31      63
# 6  31 <Age< 35      38
# 7  35 <Age< 39      35
# 8  39 <Age< 43      15
# 9  43 <Age< 47       4

# %%
df['Price'].sum()
# Out:
# 2379.77

# %%
df.head(5)
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %%
df2 = df[['Price','SN']]
print("Top 5 Spenders total purchase cost : ")
top5spenders = df2.groupby('SN')['Price'].sum().sort_values(ascending=False).head(5)
top5spenders
# Out:
# Top 5 Spenders total purchase cost :
# SN
# Lisosia93      18.96
# Idastidru52    15.45
# Chamjask73     13.83
# Iral74         13.62
# Iskadarya95    13.10
# Name: Price, dtype: float64

# %%
top5name = top5spenders.keys()

# %%
top5names  = '|'.join(top5name)
top5names
# Out:
# 'Lisosia93|Idastidru52|Chamjask73|Iral74|Iskadarya95'

# %%
print("Top 5 Spenders total items purchased : ")
df[df['SN'].str.contains(top5names)].groupby('SN')['SN'].count()
# Out:
# Top 5 Spenders total items purchased :
# SN
# Chamjask73     3
# Idastidru52    4
# Iral74         4
# Iskadarya95    3
# Lisosia93      5
# Name: SN, dtype: int64

# %%
print("Top 5 Spenders average purchase : ")
df[df['SN'].str.contains(top5names)].groupby('SN')['Price'].mean()
# Out:
# Top 5 Spenders average purchase :
# SN
# Chamjask73     4.610000
# Idastidru52    3.862500
# Iral74         3.405000
# Iskadarya95    4.366667
# Lisosia93      3.792000
# Name: Price, dtype: float64

# %%
print("Top 5 Spenders total purchase : ",top5spenders.values.sum())
# Out:
# Top 5 Spenders total purchase :  74.96000000000001

# %%
df.head(5)
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %%
top5items = df.groupby('Item Name')['Price'].count().sort_values(ascending=False).head(5)
top5items
# Out:
# Item Name
# Final Critic                                    13
# Oathbreaker, Last Hope of the Breaking Storm    12
# Persuasion                                       9
# Nirvana                                          9
# Extraction, Quickblade Of Trembling Hands        9
# Name: Price, dtype: int64

# %%
top5items = '|'.join(top5items.keys())

# %%
top5items = df[df['Item Name'].str.contains(top5items)]
top5items
# Out:
#      Purchase ID              SN  Age  Gender  Item ID  \
# 0              0         Lisim78   20    Male      108
# 2              2      Ithergue48   24    Male       92
# 18            18       Reunasu60   22  Female       82
# 24            24         Siala43   30    Male      141
# 25            25       Lisirra87   29    Male      178
# 56            56        Raesty92   12    Male      108
# 61            61      Jiskimya77   17    Male      178
# 62            62      Yadaphos40   30    Male      178
# 72            72       Marilsa69   25  Female      178
# 88            88      Laedallo55   30    Male       82
# 98            98      Chadossa89   23    Male      141
# 99            99    Haisrisuir60   23    Male      101
# 157          157        Marast30   18  Female      108
# 202          202       Phistym51   37    Male       82
# 222          222      Chamjask73   22  Female      178
# 240          240    Lirtastsda29   16    Male       82
# ...

# %%
item_id = top5items['Item ID'].unique()

# %%
top5items = top5items.set_index("Item ID")

# %%
item_names = top5items.loc[item_id]['Item Name'].unique()
for i in range(len(item_names)):
    print(f"{item_id[i]}: {item_names[i]}")
# Out:
# 108: Extraction, Quickblade Of Trembling Hands
# 92: Final Critic
# 82: Nirvana
# 141: Persuasion
# 178: Oathbreaker, Last Hope of the Breaking Storm

# %%
top5items.head()
# Out:
#          Purchase ID          SN  Age  Gender  \
# Item ID
# 108                0     Lisim78   20    Male
# 92                 2  Ithergue48   24    Male
# 82                18   Reunasu60   22  Female
# 141               24     Siala43   30    Male
# 178               25   Lisirra87   29    Male
#
#                                             Item Name  Price
# Item ID
# 108         Extraction, Quickblade Of Trembling Hands   3.53
# 92                                       Final Critic   4.88
# 82                                            Nirvana   4.90
# 141                                        Persuasion   3.19
# 178      Oathbreaker, Last Hope of the Breaking Storm   4.23

# %%
df3 = top5items.loc[item_id].groupby('Item Name')

# %%
print("Purcase count of top 5 items is")
df3['SN'].count()
# Out:
# Purcase count of top 5 items is
# Item Name
# Extraction, Quickblade Of Trembling Hands        9
# Final Critic                                    13
# Nirvana                                          9
# Oathbreaker, Last Hope of the Breaking Storm    12
# Persuasion                                       9
# Name: SN, dtype: int64

# %%
price = top5items.loc[item_id]['Price'].unique()
print("Price of each item is :")
for i in range(len(item_names)):
    print(f"{item_id[i]}: {price[i]} : {item_names[i]}")
# Out:
# Price of each item is :
# 108: 3.53 : Extraction, Quickblade Of Trembling Hands
# 92: 4.88 : Final Critic
# 82: 4.9 : Nirvana
# 141: 3.19 : Persuasion
# 178: 4.23 : Oathbreaker, Last Hope of the Breaking Storm

# %%
sum = 0
for i in price:
    sum = sum+i

print("Total purchase ammount",sum)
# Out:
# Total purchase ammount 28.25

# %%
top5items = df.groupby('Item Name')['Price'].sum().sort_values(ascending=False).head(5)
top5items
top5items = '|'.join(top5items.keys())

top5items = df[df['Item Name'].str.contains(top5items)]
top5items
item_id = top5items['Item ID'].unique()
top5items = top5items.set_index("Item ID")
item_names = top5items.loc[item_id]['Item Name'].unique()
for i in range(len(item_names)):
    print(f"{item_id[i]}: {item_names[i]}")
df3 = top5items.loc[item_id].groupby('Item Name')
print("Purcase count of top 5 items is")
df3['SN'].count()
price = top5items.loc[item_id]['Price'].unique()
print("Price of each item is :")
for i in range(len(item_names)):
    print(f"{item_id[i]}: {price[i]} : {item_names[i]}")

sum = 0
for i in price:
    sum = sum+i

print("Total purchase ammount",sum)
# Out:
# 92: Final Critic
# 82: Nirvana
# 178: Oathbreaker, Last Hope of the Breaking Storm
# 101: Fiery Glass Crusader
# 145: Singed Scalpel
# Purcase count of top 5 items is
# Price of each item is :
# 92: 4.88 : Final Critic
# 82: 4.9 : Nirvana
# 178: 4.23 : Oathbreaker, Last Hope of the Breaking Storm
# 101: 4.19 : Fiery Glass Crusader
# 145: 4.58 : Singed Scalpel
# Total purchase ammount 27.130000000000003

# %%
df_08 = pd.read_csv('all_alpha_08.csv')
df_08.tail(5)
# Out:
#             Model  Displ      Cyl    Trans Drive      Fuel Sales Area Stnd  \
# 2399  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   4WD  Gasoline         CA   U2
# 2400  VOLVO XC 90    4.4  (8 cyl)  Auto-S6   4WD  Gasoline         CA   U2
# 2401  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   2WD  Gasoline         FA   B5
# 2402  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   4WD  Gasoline         FA   B5
# 2403  VOLVO XC 90    4.4  (8 cyl)  Auto-S6   4WD  Gasoline         FA   B5
#
#       Underhood ID Veh Class Air Pollution Score FE Calc Appr City MPG  \
# 2399  8VVXB03.2U2N       SUV                   7          Drv       14
# 2400  8VVXB04.4U2N       SUV                   7          Drv       13
# 2401  8VVXB03.2U2N       SUV                   6          Drv       14
# 2402  8VVXB03.2U2N       SUV                   6          Drv       14
# 2403  8VVXB04.4U2N       SUV                   6          Drv       13
#
#      Hwy MPG Cmb MPG  Unadj Cmb MPG Greenhouse Gas Score SmartWay
# ...

# %%
df_18 = pd.read_csv('all_alpha_18.csv')
df_18.head(5)
# Out:
#        Model  Displ  Cyl       Trans Drive      Fuel Cert Region       Stnd  \
# 0  ACURA RDX    3.5  6.0  SemiAuto-6   2WD  Gasoline          FA     T3B125
# 1  ACURA RDX    3.5  6.0  SemiAuto-6   2WD  Gasoline          CA         U2
# 2  ACURA RDX    3.5  6.0  SemiAuto-6   4WD  Gasoline          FA     T3B125
# 3  ACURA RDX    3.5  6.0  SemiAuto-6   4WD  Gasoline          CA         U2
# 4  ACURA TLX    2.4  4.0       AMS-8   2WD  Gasoline          CA  L3ULEV125
#
#              Stnd Description  Underhood ID  Veh Class  Air Pollution Score  \
# 0      Federal Tier 3 Bin 125  JHNXT03.5GV3  small SUV                    3
# 1      California LEV-II ULEV  JHNXT03.5GV3  small SUV                    3
# 2      Federal Tier 3 Bin 125  JHNXT03.5GV3  small SUV                    3
# 3      California LEV-II ULEV  JHNXT03.5GV3  small SUV                    3
# 4  California LEV-III ULEV125  JHNXV02.4WH3  small car                    3
#
# ...

# %%
df_08.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2404 entries, 0 to 2403
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Model                 2404 non-null   object
#  1   Displ                 2404 non-null   float64
#  2   Cyl                   2205 non-null   object
#  3   Trans                 2205 non-null   object
#  4   Drive                 2311 non-null   object
#  5   Fuel                  2404 non-null   object
#  6   Sales Area            2404 non-null   object
#  7   Stnd                  2404 non-null   object
#  8   Underhood ID          2404 non-null   object
#  9   Veh Class             2404 non-null   object
#  10  Air Pollution Score   2404 non-null   object
#  11  FE Calc Appr          2205 non-null   object
#  12  City MPG              2205 non-null   object
#  13  Hwy MPG               2205 non-null   object
#  14  Cmb MPG               2205 non-null   object
# ...

# %%
df_08.isna().sum()
# Out:
# Model                   0
# Displ                   0
# Cyl                     0
# Trans                   0
# Drive                   0
# Fuel                    0
# Sales Area              0
# Stnd                    0
# Underhood ID            0
# Veh Class               0
# Air Pollution Score     0
# FE Calc Appr            0
# City MPG                0
# Hwy MPG                 0
# Cmb MPG                 0
# Unadj Cmb MPG           0
# Greenhouse Gas Score    0
# SmartWay                0
# dtype: int64

# %%
df_08['FE Calc Appr'] = df_08['FE Calc Appr'].astype(float)
df_08['City MPG'] = df_08['City MPG'].astype(float)
df_08['Hwy MPG'] = df_08['Hwy MPG'].astype(float)
df_08['Cmb MPG'] = df_08['Cmb MPG'].astype(float)
df_08['Unadj Cmb MPG'] = df_08['Unadj Cmb MPG'].astype(float)
df_08['Greenhouse Gas Score'] = df_08['Greenhouse Gas Score'].astype(float)

# %%
df_08['Greenhouse Gas Score'].replace({np.nan:0.72},inplace=True)
