# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
marketing = pd.read_csv('marketing.csv')
marketing
# Out:
#          ID   Education Marital_Status  Income  Kidhome  Teenhome  MntWines  \
# 0         0  Graduation        Married   70951        0         0       239
# 1         1  Graduation         Single   57091        0         0       464
# 2         9      Master         Single   46098        1         1        57
# 3        13         PhD          Widow   25358        0         1        19
# 4        17         PhD        Married   60491        0         1       637
# ...     ...         ...            ...     ...      ...       ...       ...
# 2210  11178      Master         Single   42394        1         0        15
# 2211  11181         PhD        Married  156924        0         0         2
# 2212  11187       Basic         Single   26487        1         0         2
# 2213  11188  Graduation       Together   26091        1         1        15
# 2214  11191  Graduation       Divorced   41411        0         0        37
#
# ...

# %%
plt.hist(marketing['Income'])
plt.show()

# %%
plt.hist(marketing['Income'],edgecolor='black')
plt.show()

# %%
plt.hist(marketing['Income'],bins=15,edgecolor='black')
plt.show()

# %%
sns.histplot(x='Income',data=marketing,bins=15,color='green')
plt.show()

# %%
marketing['Income'].plot.density()
plt.show()

# %%
insurance = pd.read_csv('insurance.csv')
insurance.head(10)
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520
# 5   31  female  25.740         0     no  southeast   3756.62160
# 6   46  female  33.440         1     no  southeast   8240.58960
# 7   37  female  27.740         3     no  northwest   7281.50560
# 8   37    male  29.830         2     no  northeast   6406.41070
# 9   60  female  25.840         0     no  northwest  28923.13692

# %%
plt.hist(insurance['age'])
# Out:
# (array([222., 140., 109., 128., 102., 137., 144., 114., 128., 114.]),
#  array([18. , 22.6, 27.2, 31.8, 36.4, 41. , 45.6, 50.2, 54.8, 59.4, 64. ]),
#  <BarContainer object of 10 artists>)

# %%
insurance['age'].plot.density()
plt.show()

# %%
df = pd.read_csv('ex5.csv')

# %%
df
# Out:
#   branch number  sale1  sale2  sale3
# 0       branch1    200    258    592
# 1       branch2    328    664    606
# 2       branch3    870    249    918
# 3       branch4    209    971    629

# %%
df.plot.bar(x='branch number')
plt.show()

# %%
df.plot.bar(x='branch number',subplots=True)
plt.show()

# %%
df.plot.bar(x='branch number',y='sale1')
plt.show()

# %%
df = pd.read_csv('ex5.csv',index_col = 'branch number')

# %%
df.plot.pie(y='sale1')
plt.show()

# %%
df.plot.pie(y='sale1',figsize = (11,6),autopct = '%1.1f%%',radius=4) # autopct is used for showing the percentage of the shear in the pie plot
# Out:
# <Axes: ylabel='sale1'>

# %%
df.plot.pie(subplots = True,figsize = (20,10),autopct="%1.1f%%")
# Out:
# array([<Axes: ylabel='sale1'>, <Axes: ylabel='sale2'>,
#        <Axes: ylabel='sale3'>], dtype=object)
