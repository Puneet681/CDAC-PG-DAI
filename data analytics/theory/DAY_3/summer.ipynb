# %%
import pandas as pd
summer = pd.read_csv('summer.csv',index_col='Athlete')
summer
# Out:
#                            Year    City      Sport           Discipline  \
# Athlete
# HAJOS, Alfred              1896  Athens   Aquatics             Swimming
# HERSCHMANN, Otto           1896  Athens   Aquatics             Swimming
# DRIVAS, Dimitrios          1896  Athens   Aquatics             Swimming
# MALOKINIS, Ioannis         1896  Athens   Aquatics             Swimming
# CHASAPIS, Spiridon         1896  Athens   Aquatics             Swimming
# ...                         ...     ...        ...                  ...
# JANIKOWSKI, Damian         2012  London  Wrestling  Wrestling Freestyle
# REZAEI, Ghasem Gholamreza  2012  London  Wrestling  Wrestling Freestyle
# TOTROV, Rustam             2012  London  Wrestling  Wrestling Freestyle
# ALEKSANYAN, Artur          2012  London  Wrestling  Wrestling Freestyle
# LIDBERG, Jimmy             2012  London  Wrestling  Wrestling Freestyle
#
#                           Country Gender                       Event   Medal
# Athlete
# ...

# %%
print(summer.iloc[0])
print(type(summer.iloc[0]))
# Out:
# Year                    1896
# City                  Athens
# Sport               Aquatics
# Discipline          Swimming
# Country                  HUN
# Gender                   Men
# Event         100M Freestyle
# Medal                   Gold
# Name: HAJOS, Alfred, dtype: object
# <class 'pandas.core.series.Series'>

# %%
# second index value's (Second Athlete's) record
print(summer.iloc[1])  
# last index values's (last athlete's) record
print(summer.iloc[-1])
# Out:
# Year                    1896
# City                  Athens
# Sport               Aquatics
# Discipline          Swimming
# Country                  AUT
# Gender                   Men
# Event         100M Freestyle
# Medal                 Silver
# Name: HERSCHMANN, Otto, dtype: object
# Year                         2012
# City                       London
# Sport                   Wrestling
# Discipline    Wrestling Freestyle
# Country                       SWE
# Gender                        Men
# Event                    Wg 96 KG
# Medal                      Bronze
# Name: LIDBERG, Jimmy, dtype: object

# %%
# select the second , third and fourth ( Frist Athlete's) rows
print(summer.iloc[[1,2,3]])
# Out:
#                     Year    City     Sport Discipline Country Gender  \
# Athlete
# HERSCHMANN, Otto    1896  Athens  Aquatics   Swimming     AUT    Men
# DRIVAS, Dimitrios   1896  Athens  Aquatics   Swimming     GRE    Men
# MALOKINIS, Ioannis  1896  Athens  Aquatics   Swimming     GRE    Men
#
#                                          Event   Medal
# Athlete
# HERSCHMANN, Otto                100M Freestyle  Silver
# DRIVAS, Dimitrios   100M Freestyle For Sailors  Bronze
# MALOKINIS, Ioannis  100M Freestyle For Sailors    Gold

# %%
#  select the second to fourth athlete's rows
summer.iloc[1:5]
# Out:
#                     Year    City     Sport Discipline Country Gender  \
# Athlete
# HERSCHMANN, Otto    1896  Athens  Aquatics   Swimming     AUT    Men
# DRIVAS, Dimitrios   1896  Athens  Aquatics   Swimming     GRE    Men
# MALOKINIS, Ioannis  1896  Athens  Aquatics   Swimming     GRE    Men
# CHASAPIS, Spiridon  1896  Athens  Aquatics   Swimming     GRE    Men
#
#                                          Event   Medal
# Athlete
# HERSCHMANN, Otto                100M Freestyle  Silver
# DRIVAS, Dimitrios   100M Freestyle For Sailors  Bronze
# MALOKINIS, Ioannis  100M Freestyle For Sailors    Gold
# CHASAPIS, Spiridon  100M Freestyle For Sailors  Silver

# %%
summer.iloc[:5]
# Out:
#                     Year    City     Sport Discipline Country Gender  \
# Athlete
# HAJOS, Alfred       1896  Athens  Aquatics   Swimming     HUN    Men
# HERSCHMANN, Otto    1896  Athens  Aquatics   Swimming     AUT    Men
# DRIVAS, Dimitrios   1896  Athens  Aquatics   Swimming     GRE    Men
# MALOKINIS, Ioannis  1896  Athens  Aquatics   Swimming     GRE    Men
# CHASAPIS, Spiridon  1896  Athens  Aquatics   Swimming     GRE    Men
#
#                                          Event   Medal
# Athlete
# HAJOS, Alfred                   100M Freestyle    Gold
# HERSCHMANN, Otto                100M Freestyle  Silver
# DRIVAS, Dimitrios   100M Freestyle For Sailors  Bronze
# MALOKINIS, Ioannis  100M Freestyle For Sailors    Gold
# CHASAPIS, Spiridon  100M Freestyle For Sailors  Silver

# %%
summer.iloc[:3]
# Out:
#                    Year    City     Sport Discipline Country Gender  \
# Athlete
# HAJOS, Alfred      1896  Athens  Aquatics   Swimming     HUN    Men
# HERSCHMANN, Otto   1896  Athens  Aquatics   Swimming     AUT    Men
# DRIVAS, Dimitrios  1896  Athens  Aquatics   Swimming     GRE    Men
#
#                                         Event   Medal
# Athlete
# HAJOS, Alfred                  100M Freestyle    Gold
# HERSCHMANN, Otto               100M Freestyle  Silver
# DRIVAS, Dimitrios  100M Freestyle For Sailors  Bronze

# %%
summer.iloc[-3:]
# Out:
#                    Year    City      Sport           Discipline Country  \
# Athlete
# TOTROV, Rustam     2012  London  Wrestling  Wrestling Freestyle     RUS
# ALEKSANYAN, Artur  2012  London  Wrestling  Wrestling Freestyle     ARM
# LIDBERG, Jimmy     2012  London  Wrestling  Wrestling Freestyle     SWE
#
#                   Gender     Event   Medal
# Athlete
# TOTROV, Rustam       Men  Wg 96 KG  Silver
# ALEKSANYAN, Artur    Men  Wg 96 KG  Bronze
# LIDBERG, Jimmy       Men  Wg 96 KG  Bronze

# %%
summer.iloc[3:-3]
# Out:
#                               Year    City      Sport           Discipline  \
# Athlete
# MALOKINIS, Ioannis            1896  Athens   Aquatics             Swimming
# CHASAPIS, Spiridon            1896  Athens   Aquatics             Swimming
# CHOROPHAS, Efstathios         1896  Athens   Aquatics             Swimming
# HAJOS, Alfred                 1896  Athens   Aquatics             Swimming
# ANDREOU, Joannis              1896  Athens   Aquatics             Swimming
# ...                            ...     ...        ...                  ...
# KHUGAEV, Alan                 2012  London  Wrestling  Wrestling Freestyle
# EBRAHIM, Karam Mohamed Gaber  2012  London  Wrestling  Wrestling Freestyle
# GAJIYEV, Danyal               2012  London  Wrestling  Wrestling Freestyle
# JANIKOWSKI, Damian            2012  London  Wrestling  Wrestling Freestyle
# REZAEI, Ghasem Gholamreza     2012  London  Wrestling  Wrestling Freestyle
#
# ...

# %%
summer.iloc[[1,2,4],[2,3,4]]
# Out:
#                        Sport Discipline Country
# Athlete
# HERSCHMANN, Otto    Aquatics   Swimming     AUT
# DRIVAS, Dimitrios   Aquatics   Swimming     GRE
# CHASAPIS, Spiridon  Aquatics   Swimming     GRE

# %%
summer.iloc[34:45,[3,4]]
summer.loc['DAMASKOS, Evangelos'][4]
# Out:
# 'GRE'

# %%
group = summer.groupby('Country') # convert group into list to properly understand group structure of data - group is as object
l = list(group)
l

# %%
import numpy as np
a = np.array([9,7,10,8,9,7,8,9])
u = np.mean(a)

v = np.sum((a-u)**2)
v

sd = np.sqrt(v)
